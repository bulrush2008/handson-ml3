# %%
import pandas as pd

df = pd.read_excel('https://www.gairuo.com/file/data/dataset/team.xlsx')

# %%
df
# Out:
#         name team  Q1  Q2  Q3  Q4
# 0      Liver    E  89  21  24  64
# 1       Arry    C  36  37  37  57
# 2        Ack    A  57  60  18  84
# 3      Eorge    C  93  96  71  78
# 4        Oah    D  65  49  61  86
# ..       ...  ...  ..  ..  ..  ..
# 95   Gabriel    C  48  59  87  74
# 96   Austin7    C  21  31  30  43
# 97  Lincoln4    C  98  93   1  20
# 98       Eli    E  11  74  58  91
# 99       Ben    E  21  43  41  74
#
# [100 rows x 6 columns]

# %%
df.head()
# Out:
#     name team  Q1  Q2  Q3  Q4
# 0  Liver    E  89  21  24  64
# 1   Arry    C  36  37  37  57
# 2    Ack    A  57  60  18  84
# 3  Eorge    C  93  96  71  78
# 4    Oah    D  65  49  61  86

# %%
df.tail()
# Out:
#         name team  Q1  Q2  Q3  Q4
# 95   Gabriel    C  48  59  87  74
# 96   Austin7    C  21  31  30  43
# 97  Lincoln4    C  98  93   1  20
# 98       Eli    E  11  74  58  91
# 99       Ben    E  21  43  41  74

# %%
df.sample(3)
# Out:
#        name team  Q1  Q2  Q3  Q4
# 5    Harlie    C  24  13  87  43
# 49  Carter7    D  57  52  77  50
# 23    Mason    D  80  96  26  49

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    100 non-null    object
#  1   team    100 non-null    object
#  2   Q1      100 non-null    int64
#  3   Q2      100 non-null    int64
#  4   Q3      100 non-null    int64
#  5   Q4      100 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 4.8+ KB

# %%
df.shape
# Out:
# (100, 6)

# %%
df.describe()
# Out:
#                Q1          Q2          Q3          Q4
# count  100.000000  100.000000  100.000000  100.000000
# mean    49.200000   52.550000   52.670000   52.780000
# std     29.962603   29.845181   26.543677   27.818524
# min      1.000000    1.000000    1.000000    2.000000
# 25%     19.500000   26.750000   29.500000   29.500000
# 50%     51.500000   49.500000   55.000000   53.000000
# 75%     74.250000   77.750000   76.250000   75.250000
# max     98.000000   99.000000   99.000000   99.000000

# %%
df.dtypes
# Out:
# name    object
# team    object
# Q1       int64
# Q2       int64
# Q3       int64
# Q4       int64
# dtype: object

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['name', 'team', 'Q1', 'Q2', 'Q3', 'Q4'], dtype='object')]

# %%
df.columns
# Out:
# Index(['name', 'team', 'Q1', 'Q2', 'Q3', 'Q4'], dtype='object')

# %%
df.set_index("name")
# Out:
#          team  Q1  Q2  Q3  Q4
# name
# Liver       E  89  21  24  64
# Arry        C  36  37  37  57
# Ack         A  57  60  18  84
# Eorge       C  93  96  71  78
# Oah         D  65  49  61  86
# ...       ...  ..  ..  ..  ..
# Gabriel     C  48  59  87  74
# Austin7     C  21  31  30  43
# Lincoln4    C  98  93   1  20
# Eli         E  11  74  58  91
# Ben         E  21  43  41  74
#
# [100 rows x 5 columns]

# %%
df.Q1
# Out:
# 0     89
# 1     36
# 2     57
# 3     93
# 4     65
#       ..
# 95    48
# 96    21
# 97    98
# 98    11
# 99    21
# Name: Q1, Length: 100, dtype: int64

# %%
#df[['Eli']] # no choosing row, wrong! 
df[df.index=='Liver']
# Out:
# Empty DataFrame
# Columns: [name, team, Q1, Q2, Q3, Q4]
# Index: []

# %%
df[0:3]
# Out:
#     name team  Q1  Q2  Q3  Q4
# 0  Liver    E  89  21  24  64
# 1   Arry    C  36  37  37  57
# 2    Ack    A  57  60  18  84

# %%
df[df.index=='Ack']
# Out:
# Empty DataFrame
# Columns: [name, team, Q1, Q2, Q3, Q4]
# Index: []

# %%
df[3:4]
# Out:
#     name team  Q1  Q2  Q3  Q4
# 3  Eorge    C  93  96  71  78

# %%
df[['team', 'Q1']]
# Out:
#    team  Q1
# 0     E  89
# 1     C  36
# 2     A  57
# 3     C  93
# 4     D  65
# ..  ...  ..
# 95    C  48
# 96    C  21
# 97    C  98
# 98    E  11
# 99    E  21
#
# [100 rows x 2 columns]

# %%
df.loc[:,['team', 'Q1']]
# Out:
#    team  Q1
# 0     E  89
# 1     C  36
# 2     A  57
# 3     C  93
# 4     D  65
# ..  ...  ..
# 95    C  48
# 96    C  21
# 97    C  98
# 98    E  11
# 99    E  21
#
# [100 rows x 2 columns]

# %%
df['Q1'].plot()
df
# Out:
#         name team  Q1  Q2  Q3  Q4
# 0      Liver    E  89  21  24  64
# 1       Arry    C  36  37  37  57
# 2        Ack    A  57  60  18  84
# 3      Eorge    C  93  96  71  78
# 4        Oah    D  65  49  61  86
# ..       ...  ...  ..  ..  ..  ..
# 95   Gabriel    C  48  59  87  74
# 96   Austin7    C  21  31  30  43
# 97  Lincoln4    C  98  93   1  20
# 98       Eli    E  11  74  58  91
# 99       Ben    E  21  43  41  74
#
# [100 rows x 6 columns]

# %%
# multiple lines
df.loc['Eli','Q1':'Q4']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 2
#       1 # multiple lines
# ----> 2 df.loc['Eli','Q1':'Q4']
#
# File ~/.conda/envs/GeronE3/lib/python3.12/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~/.conda/envs/GeronE3/lib/python3.12/site-packages/pandas/core/indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1366 with suppress(IndexingError):
#    1367     tup = self._expand_ellipsis(tup)
# -> 1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
# ...
